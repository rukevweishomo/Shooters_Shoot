# %% [markdown]
# # Back to the Drawing Board
# I'm using this notebook to test the logic of the helper functions in my "features" python file, just to make sure they work.

# %%
import sys, os
import pandas as pd
sys.path.insert(0, os.path.abspath('..'))
import src.features as features
from src.consts import *
from src.features import feature_engineering, get_feature_cols, get_coords

df = pd.read_parquet('../data/shot_data.parquet')

X, Y = get_coords(df)
print(X.head())
print(Y.head())
# Out:
#                   ACTION_TYPE  LOC_X  LOC_Y  SHOT_DISTANCE       SHOT_TYPE  \
# 0          Driving Layup Shot  -17.0   -6.0            1.0  2PT Field Goal
# 1         Step Back Jump shot  117.0   67.0           13.0  2PT Field Goal
# 2         Step Back Jump shot   76.0   95.0           12.0  2PT Field Goal
# 3  Driving Floating Jump Shot  -68.0   51.0            8.0  2PT Field Goal
# 4                   Jump Shot -117.0  164.0           20.0  2PT Field Goal
#
#    PERIOD  MINUTES_REMAINING  SECONDS_REMAINING  \
# 0       1                 11                 41
# 1       1                 11                 21
# 2       1                 11                  0
# 3       1                 10                 44
# 4       1                 10                 27
#
#    SHOT_ZONE_BASIC_Above the Break 3  SHOT_ZONE_BASIC_Backcourt  ...  \
# 0                              False                      False  ...
# 1                              False                      False  ...
# ...
